# %% [markdown]
# # 2a - Create Sentinel 2 time series for McKinley Mine seeding units
# This notebook creates Sentinel 2 time series of NDVI or other band ratios for each seeding unit created by notebook 1.

# %%
# Import libraries
import os
import datetime
from datetime import date
import configparser
import copy

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Import custom module for this project
from vegrestoretools import FisToDataframe, EvalScripts, FisClean

from sentinelhub import SHConfig, FisRequest, BBox, Geometry, CRS, WcsRequest, CustomUrlParam, \
    DataCollection, HistogramType
from sentinelhub.time_utils import iso_to_datetime, parse_time

# %%
# Read SentinelHub configuration ID's from your local ini file
config_ini = configparser.ConfigParser()
config_ini.read('sentinel2_setup.ini')

# Populate a SentinelHub configuration object with the ID's from the local ini file
config = SHConfig()
config.instance_id = config_ini['Config']['instance_id'] # Instance ID for the Configuration
config.sh_client_id = config_ini['Config']['sh_client_id'] # Credentials from the OAuth client
config.sh_client_secret = config_ini['Config']['sh_client_secret']
config.save()

# %%
# Other parameters
startDate = '2017-01-01'

# %%
# Set working directory
os.chdir(os.path.join('D:/',
                      'McKinley'))

# %% [markdown]
# ## Restore seeding unit geodataframe

# %%
# %store -r mckinley_seeding_subset_PARlo
mckinley_seeding_subset_PARlo
# Out:
#      Mine_Area  Start_Year  End_Year   GIS_Acre2          Agreement  \
# 172         9N        2017      2017    8.774365  Permanent Program
# 816       None        2013      2013   55.702517  Permanent Program
# 913       None        2013      2013   45.834100  Permanent Program
# 916       None        2013      2013  166.414201  Permanent Program
# 1265        10        2013      2013    5.505459  Permanent Program
# 1314        11        2013      2013   96.634051  Permanent Program
# 1319        11        2013      2013   11.045688  Permanent Program
# 1558      None        2014      2014   83.281620  Permanent Program
# 1588      None        2014      2014    7.462737  Permanent Program
# 1589      None        2014      2014   10.456143  Permanent Program
# 1590      None        2014      2014   33.237169  Permanent Program
# 1594      None        2014      2014    9.954058  Permanent Program
# 1601      None        2014      2014   53.183588  Permanent Program
# 1608      None        2014      2014    5.159785  Permanent Program
# 1655      None        2014      2014    4.809512  Permanent Program
# 2335      None        2015      2015    7.430665  Permanent Program
# 2569        12        2017      2017   13.038010  Permanent Program
# 2577      None        2017      2017   83.281620  Permanent Program
# 2581        9N        2018      2018    7.102141  Permanent Program
# 2584      None        2018      2018   13.084191  Permanent Program
# 2586      None        2018      2018   15.087941  Permanent Program
# 2587      None        2018      2018    5.845416  Permanent Program
# 2599      None        2018      2018   12.019538  Permanent Program
# 2600      None        2018      2018   11.951126  Permanent Program
# 2601      None        2018      2018   15.077256  Permanent Program
# 2604      None        2018      2018    4.922479  Permanent Program
# 2609        9N        2019      2019    6.119263  Permanent Program
# 2614        9N        2019      2019    6.584653  Permanent Program
# 2615        9N        2019      2019   17.708491  Permanent Program
# 2616        9N        2019      2019   18.509379  Permanent Program
# 2620      None        2019      2019    8.773573  Permanent Program
# 2621      None        2019      2019    4.621539  Permanent Program
# 2622      None        2019      2019   21.389559  Permanent Program
# 2623      None        2019      2019   12.487979  Permanent Program
# 2624      None        2019      2019   18.117589  Permanent Program
# 2626      None        2019      2019   14.584721  Permanent Program
# 2627      None        2019      2019   16.298974  Permanent Program
# 2628      None        2019      2019   15.185447  Permanent Program
# 2633      None        2019      2019    4.935714  Permanent Program
# 2634      None        2019      2019    4.069068  Permanent Program
# 2645      None        2019      2019    6.954194  Permanent Program
# 2646      None        2019      2019    4.830405  Permanent Program
# 2648      None        2019      2019    7.350496  Permanent Program
# 2650      None        2019      2019   49.372159  Permanent Program
#
#       Seed_Type                     TYPE  \
# 172        Seed                  Seeding
# 816        Seed                  Seeding
# 913        Seed                  Seeding
# 916        Seed                  Seeding
# 1265     Reseed                Reseeding
# 1314       Seed                  Seeding
# 1319       Seed                  Seeding
# 1558     Reseed                Reseeding
# 1588     Reseed                Reseeding
# 1589     Reseed                Reseeding
# 1590     Reseed                Reseeding
# 1594       Seed                  Seeding
# 1601     Reseed                Reseeding
# 1608     Reseed                Reseeding
# 1655     Reseed                Reseeding
# 2335  Interseed             Interseeding
# 2569       Seed                  Seeding
# 2577  Interseed             Interseeding
# 2581  Interseed             Interseeding
# 2584  Interseed    Interseeding_Wildlife
# 2586  Interseed    Interseeding_Wildlife
# 2587  Interseed  Interseeding_Wood_Mulch
# 2599  Interseed    Interseeding_Wildlife
# 2600  Interseed    Interseeding_Wildlife
# 2601  Interseed    Interseeding_Wildlife
# 2604  Interseed    Interseeding_Wildlife
# 2609  Interseed             Interseeding
# 2614  Interseed             Interseeding
# 2615  Interseed             Interseeding
# 2616  Interseed             Interseeding
# 2620  Interseed    Interseeding_Wildlife
# 2621  Interseed    Interseeding_Wildlife
# 2622  Interseed    Interseeding_Wildlife
# 2623  Interseed    Interseeding_Wildlife
# 2624  Interseed             Interseeding
# 2626  Interseed    Interseeding_Wildlife
# 2627  Interseed    Interseeding_Wildlife
# 2628  Interseed    Interseeding_Wildlife
# 2633  Interseed    Interseeding_Wildlife
# 2634  Interseed    Interseeding_Wildlife
# 2645  Interseed    Interseeding_Wildlife
# 2646     Reseed                Reseeding
# 2648  Interseed             Interseeding
# 2650  Interseed             Interseeding
#
#                                                geometry       PAR
# 172   POLYGON ((2401075.334 1683413.202, 2401068.257...  0.007403
# 816   POLYGON ((2378986.229 1702322.589, 2378982.791...  0.008140
# 913   MULTIPOLYGON (((2403966.161 1702249.371, 24039...  0.008526
# 916   POLYGON ((2398388.920 1703880.919, 2398403.538...  0.009537
# 1265  POLYGON ((2385163.827 1693999.402, 2385155.351...  0.009982
# 1314  POLYGON ((2399754.113 1695408.235, 2399762.904...  0.003032
# 1319  POLYGON ((2399974.214 1696112.931, 2399974.230...  0.009493
# 1558  POLYGON ((2402224.363 1715573.020, 2402213.169...  0.005979
# 1588  POLYGON ((2404782.569 1706591.781, 2404802.102...  0.009511
# 1589  POLYGON ((2409735.763 1703942.635, 2409767.743...  0.007148
# 1590  POLYGON ((2410168.347 1703771.145, 2410199.023...  0.008895
# 1594  POLYGON ((2381675.048 1693487.569, 2381676.234...  0.007736
# 1601  POLYGON ((2405934.085 1705844.372, 2405934.591...  0.004474
# 1608  POLYGON ((2385953.016 1697100.768, 2385954.042...  0.009365
# 1655  POLYGON ((2405047.814 1700561.683, 2404796.373...  0.009968
# 2335  POLYGON ((2381803.834 1693489.254, 2381823.815...  0.008307
# 2569  POLYGON ((2400287.872 1697144.026, 2400287.166...  0.009437
# 2577  POLYGON ((2402224.363 1715573.020, 2402213.169...  0.005979
# 2581  POLYGON ((2400828.909 1683504.400, 2400808.216...  0.007412
# 2584  POLYGON ((2401028.139 1720753.878, 2401027.664...  0.006117
# 2586  POLYGON ((2401946.926 1716151.222, 2401824.882...  0.008767
# 2587  POLYGON ((2401835.166 1715209.990, 2401810.280...  0.008770
# 2599  POLYGON ((2392291.817 1709223.194, 2392253.922...  0.006145
# 2600  POLYGON ((2391567.873 1708592.092, 2391322.372...  0.006227
# 2601  POLYGON ((2389060.565 1707378.088, 2388751.565...  0.005095
# 2604  POLYGON ((2388704.329 1697645.798, 2388719.686...  0.009995
# 2609  POLYGON ((2399014.787 1680754.426, 2399000.024...  0.009593
# 2614  POLYGON ((2397042.167 1679624.202, 2397047.683...  0.007437
# 2615  POLYGON ((2397968.988 1679732.345, 2397976.396...  0.007466
# 2616  POLYGON ((2398408.024 1678953.157, 2398425.143...  0.006601
# 2620  POLYGON ((2389854.196 1703967.281, 2389853.700...  0.006396
# 2621  POLYGON ((2391121.623 1701925.786, 2391113.747...  0.009909
# 2622  POLYGON ((2389501.224 1701476.566, 2389506.807...  0.004941
# 2623  POLYGON ((2399791.699 1713560.687, 2399782.940...  0.006156
# 2624  POLYGON ((2393549.524 1710972.353, 2393555.109...  0.006013
# 2626  POLYGON ((2406351.256 1701731.202, 2406370.273...  0.007911
# 2627  POLYGON ((2408358.529 1703163.333, 2408344.051...  0.006150
# 2628  POLYGON ((2402423.091 1704858.806, 2402426.467...  0.005212
# 2633  POLYGON ((2395737.521 1710043.792, 2395548.684...  0.009983
# 2634  POLYGON ((2399231.024 1711967.785, 2399227.792...  0.009876
# 2645  POLYGON ((2400582.550 1701147.411, 2400589.578...  0.008810
# 2646  POLYGON ((2398238.925 1700967.351, 2398244.226...  0.009492
# 2648  POLYGON ((2397437.054 1703154.667, 2397439.018...  0.008919
# 2650  POLYGON ((2398828.096 1700499.711, 2398861.829...  0.004498

# %% [markdown]
# ## Run SentinelHub Statistical Info Service (FIS) query

# %%
seeding_aois = mckinley_seeding_subset_PARlo

# Convert seeding polygons to WGS84
seeding_aois = seeding_aois.to_crs("EPSG:4326")

# Explode multipolygons to polygons to query with FIS request
seeding_aois_exploded = seeding_aois.explode()

# Create empty list to store results for all polygons
output_list = []

# Loop over each polygon
for index, row in seeding_aois_exploded.iterrows():

    # Status message
    print('Now processing Seeding Unit Index: ' + str(index[0]))

    # Setup parameters for FIS request
    geometry_list = Geometry(row.geometry, CRS.WGS84)
    time_interval = (startDate, date.today())

    # Retrieve custom script to pass to SentinelHub from vegrestoretools module
    evalscript = EvalScripts('Sentinel_2_NDVI')

    # Build FIS request
    fis_request = FisRequest(
        data_collection=DataCollection.SENTINEL2_L2A,
        layer='BANDS-S2-L2A',
        geometry_list=[geometry_list],
        time=time_interval,
        resolution='100m',
        custom_url_params={CustomUrlParam.EVALSCRIPT: evalscript},
        config=config
    )

    # Run the FIS request
    fis_data = fis_request.get_data()

    # Convert the FIS result to a dataframe
    fis_df = FisToDataframe(fis_data)

    # Add the seeding unit ID to the dataframe
    fis_df['ID'] = index[0]

    # Append the df to the temporary list
    output_list.append(fis_df)

# Concatenate the VMU results into a single DF
fis_df_all_raw = pd.concat(output_list, axis=0)
fis_df_all_raw
# Out:
# Now processing Seeding Unit Index: 172
# Now processing Seeding Unit Index: 816
# Now processing Seeding Unit Index: 913
# Now processing Seeding Unit Index: 913
# Now processing Seeding Unit Index: 916
# Now processing Seeding Unit Index: 1265
# Now processing Seeding Unit Index: 1314
# Now processing Seeding Unit Index: 1319
# Now processing Seeding Unit Index: 1558
# Now processing Seeding Unit Index: 1588
# Now processing Seeding Unit Index: 1589
# Now processing Seeding Unit Index: 1590
# Now processing Seeding Unit Index: 1594
# Now processing Seeding Unit Index: 1601
# Now processing Seeding Unit Index: 1608
# Now processing Seeding Unit Index: 1655
# Now processing Seeding Unit Index: 2335
# Now processing Seeding Unit Index: 2569
# Now processing Seeding Unit Index: 2577
# Now processing Seeding Unit Index: 2581
# Now processing Seeding Unit Index: 2584
# Now processing Seeding Unit Index: 2586
# Now processing Seeding Unit Index: 2587
# Now processing Seeding Unit Index: 2599
# Now processing Seeding Unit Index: 2600
# Now processing Seeding Unit Index: 2601
# Now processing Seeding Unit Index: 2604
# Now processing Seeding Unit Index: 2609
# Now processing Seeding Unit Index: 2614
# Now processing Seeding Unit Index: 2615
# Now processing Seeding Unit Index: 2616
# Now processing Seeding Unit Index: 2620
# Now processing Seeding Unit Index: 2621
# Now processing Seeding Unit Index: 2622
# Now processing Seeding Unit Index: 2623
# Now processing Seeding Unit Index: 2624
# Now processing Seeding Unit Index: 2626
# Now processing Seeding Unit Index: 2627
# Now processing Seeding Unit Index: 2628
# Now processing Seeding Unit Index: 2633
# Now processing Seeding Unit Index: 2634
# Now processing Seeding Unit Index: 2645
# Now processing Seeding Unit Index: 2646
# Now processing Seeding Unit Index: 2648
# Now processing Seeding Unit Index: 2650
#            date       min       max      mean     stDev  clm_mean    snw_mean  \
# 0    2021-05-31 -0.011235 -0.003757 -0.008904  0.003023       1.0  100.500000
# 1    2021-05-29  0.097798  0.131056  0.108121  0.013485       0.0    0.000000
# 2    2021-05-26  0.040423  0.070128  0.054129  0.011546       1.0    0.000000
# 3    2021-05-24  0.093460  0.145264  0.110174  0.020601       0.0    0.000000
# 4    2021-05-21 -0.009225  0.016267  0.004830  0.009395       1.0    0.250000
# ..          ...       ...       ...       ...       ...       ...         ...
# 536  2017-02-21  0.097730  0.149043  0.116268  0.010677       0.0    0.000000
# 537  2017-02-14 -0.015393  0.025167  0.001644  0.007732       1.0    0.000000
# 538  2017-02-04 -0.076547  0.513308  0.031470  0.118355       0.0   36.900000
# 539  2017-02-01 -0.057969  0.070926 -0.026381  0.030557       0.0   83.100000
# 540  2017-01-25 -0.057325  0.026265 -0.013573  0.020576       0.5   62.833333
#
#        ID
# 0     172
# 1     172
# 2     172
# 3     172
# 4     172
# ..    ...
# 536  2650
# 537  2650
# 538  2650
# 539  2650
# 540  2650
#
# [24345 rows x 8 columns]

# %% [markdown]
# ## Clean up the FIS results

# %%
fis_df_all = FisClean(fis_df_all_raw)
fis_df_all
# Out:
#               ID       min       max      mean     stDev  clm_mean  snw_mean
# date
# 2017-02-21   172  0.105520  0.180918  0.127385  0.031246       0.0       0.0
# 2017-03-13   172  0.088841  0.165789  0.112921  0.030896       0.0       0.0
# 2017-04-12   172  0.075881  0.194825  0.120009  0.046784       0.0       0.0
# 2017-04-15   172  0.080686  0.205191  0.128965  0.048003       0.0       0.0
# 2017-04-22   172  0.073243  0.204739  0.124583  0.051938       0.0       0.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 2021-05-11  2650  0.087706  0.139262  0.117857  0.012438       0.0       0.0
# 2021-05-14  2650  0.101309  0.155668  0.132854  0.013285       0.0       0.0
# 2021-05-16  2650  0.093609  0.151339  0.128688  0.012489       0.0       0.0
# 2021-05-24  2650  0.108791  0.159324  0.139050  0.012475       0.0       0.0
# 2021-05-29  2650  0.094639  0.142974  0.127912  0.011766       0.0       0.0
#
# [9856 rows x 7 columns]

# %% [markdown]
# ## Plot the results

# %%
# Setup plot
fig, ax = plt.subplots(figsize=(15, 10))

# Build list of unique sites for legend
sites = fis_df_all.ID.unique()

fis_df_all.reset_index().groupby('ID').plot(x='date', y='mean', ax=ax)

# Legend and labels
plt.legend(sites)

plt.xlabel("Date", fontsize=20)
plt.ylabel("NDVI", fontsize=20)

ax.set_title(
    "Sentinel 2 NDVI time series for McKinley Mine Vegetation Management Units", fontsize=20)

plt.setp(ax.get_xticklabels(), rotation=90, horizontalalignment='right')

plt.show()

# %% [markdown]
# ## Make DF tables consistent between Sentinel 2 and Landsat 8 data

# %%
sentinel_2_time_series = copy.deepcopy(fis_df_all)

# Drop columns
sentinel_2_time_series.drop(columns=['min', 'max', 'stDev', 'clm_mean', 'snw_mean'], inplace=True)

# Rename columns
sentinel_2_time_series.rename(
                columns={"mean": 'MeanNdvi'}, inplace=True)

sentinel_2_time_series.rename(
                columns={"ID": 'SuId'}, inplace=True)


sentinel_2_time_series
# Out:
#             SuId  MeanNdvi
# date
# 2017-02-21   172  0.127385
# 2017-03-13   172  0.112921
# 2017-04-12   172  0.120009
# 2017-04-15   172  0.128965
# 2017-04-22   172  0.124583
# ...          ...       ...
# 2021-05-11  2650  0.117857
# 2021-05-14  2650  0.132854
# 2021-05-16  2650  0.128688
# 2021-05-24  2650  0.139050
# 2021-05-29  2650  0.127912
#
# [9856 rows x 2 columns]

# %% [markdown]
# ## Save the DF for use in subsequent notebooks

# %%
# %store sentinel_2_time_series
# Out:
# Stored 'sentinel_2_time_series' (DataFrame)
